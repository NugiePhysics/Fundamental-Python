# %% [markdown]
# <a href="https://colab.research.google.com/github/NugiePhysics/Fundamental-Python/blob/main/01_Variable_dan_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greeting = 'Hello World!' # Ini adalah assignment
print(greeting)
# Out:
# Hello World!

# %%
addition = 2+2
result = addition - 1
print(result)
# Out:
# 3
